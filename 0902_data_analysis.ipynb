# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series

drive_path = r'C:/Users/kyung/Desktop/data_visu/covid_dataset/'

# %% [markdown]
# ### 사례
# * 케이스 아이디
# * 지역(특별시, 광역시, 도)
# * 도시(시, 군, 구)
# * 집단감염여부
# * 감염경로
# * 누적
# * 확진자수
# * 위도
# * 경도

# %%
case = pd.read_csv(drive_path + 'Case.csv')
print(case.info())
case.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   case_id         128 non-null    int64
#  1   province        128 non-null    object
#  2   city            128 non-null    object
#  3   group           128 non-null    bool
#  4   infection_case  128 non-null    object
#  5   confirmed       125 non-null    float64
#  6   latitude        128 non-null    object
#  7   longitude       128 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(5)
# memory usage: 7.2+ KB
# None
#     case_id province             city  group                   infection_case  \
# 0   1000001    Seoul       Yongsan-gu   True                    Itaewon Clubs
# 1   1000002    Seoul          Guro-gu   True              Guro-gu Call Center
# 2   1000003    Seoul    Dongdaemun-gu   True                    Dongan Church
# ...

# %%
case[case['confirmed'].isnull() == True]
# Out:
#     case_id province             city  group                   infection_case  \
# 13  1000014    Seoul  form other city   True        Guri Collective Infection
# 14  1000015    Seoul          Jung-gu   True                KB Life Insurance
# 15  1000016    Seoul  Yeongdeungpo-gu   True  Yeongdeungpo Learning Institute
#
#     confirmed   latitude   longitude
# 13        NaN          -           -
# 14        NaN  37.560899  126.966998
# 15        NaN  37.520846  126.931278

# %%
case[case['group'] == True]
# Out:
#      case_id          province             city  group  \
# 0    1000001             Seoul       Yongsan-gu   True
# 1    1000002             Seoul          Guro-gu   True
# 2    1000003             Seoul    Dongdaemun-gu   True
# 3    1000004             Seoul          Guro-gu   True
# 4    1000005             Seoul     Eunpyeong-gu   True
# ..       ...               ...              ...    ...
# 117  6100004  Gyeongsangnam-do         Jinju-si   True
# 118  6100005  Gyeongsangnam-do      Changwon-si   True
# 119  6100006  Gyeongsangnam-do  Changnyeong-gun   True
# 120  6100007  Gyeongsangnam-do  from other city   True
# 127  7000004           Jeju-do  from other city   True
#
#                     infection_case  confirmed   latitude   longitude
# 0                    Itaewon Clubs      133.0  37.538621  126.992652
# 1              Guro-gu Call Center       99.0  37.508163  126.884387
# 2                    Dongan Church       20.0  37.592888  127.056766
# ...

# %%
case[case['infection_case'] == 'Shincheonji Church']
# Out:
#      case_id           province             city  group      infection_case  \
# 12   1000013              Seoul  from other city   True  Shincheonji Church
# 20   1100002              Busan  from other city   True  Shincheonji Church
# 29   1200001              Daegu           Nam-gu   True  Shincheonji Church
# 39   1300001            Gwangju  from other city   True  Shincheonji Church
# 46   1400004            Incheon  from other city   True  Shincheonji Church
# 51   1500002            Daejeon  from other city   True  Shincheonji Church
# 56   1600001              Ulsan  from other city   True  Shincheonji Church
# 62   1700003             Sejong  from other city   True  Shincheonji Church
# 70   2000005        Gyeonggi-do  from other city   True  Shincheonji Church
# 78   3000001         Gangwon-do  from other city   True  Shincheonji Church
# 84   4000001  Chungcheongbuk-do  from other city   True  Shincheonji Church
# ...

# %%
case['infection_case'].unique()
# Out:
# array(['Itaewon Clubs', 'Guro-gu Call Center', 'Dongan Church',
#        'Manmin Central Church', "Eunpyeong St. Mary's Hospital",
#        'Seongdong-gu APT', 'Jongno Community Center',
#        'Samsung Medical Center', 'Jung-gu Fashion Company',
#        'Yeonana News Class', 'Korea Campus Crusade of Christ',
#        'Coupang Logistics Center', 'Shincheonji Church',
#        'Guri Collective Infection', 'KB Life Insurance',
#        'Yeongdeungpo Learning Institute', 'overseas inflow',
#        'contact with patient', 'etc', 'Onchun Church',
#        'Suyeong-gu Kindergarten', 'Haeundae-gu Catholic Church',
#        'Jin-gu Academy', 'Cheongdo Daenam Hospital',
#        'Second Mi-Ju Hospital', 'Hansarang Convalescent Hospital',
#        'Daesil Convalescent Hospital', 'Fatima Hospital',
#        'Korea Forest Engineer Institute', 'Seosan-si Laboratory',
#        'Ministry of Oceans and Fisheries', 'gym facility in Sejong',
# ...

# %% [markdown]
# -------------------------------------
# ### 환자정보
#
# * 환자id
# * 질병관리본부 부여번호
# * 성별
# * 출생연도
# * 나이
# * 국적
# * 지역
# * 기저질환 여부
# * 감염경로
# * 감염순서(몇차 감염인지)
# * 전파자 id
# * 접촉자수
# * 증상발현일
# * 확진일
# * 완치일
# * 사망일
# * 상태(격리, 완치, 사망)

# %%
patient_info = pd.read_csv(drive_path + 'PatientInfo.csv')
print(patient_info.info())
patient_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4004 entries, 0 to 4003
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          4004 non-null   int64
#  1   global_num          2806 non-null   float64
#  2   sex                 3674 non-null   object
#  3   birth_year          3267 non-null   object
#  4   age                 3525 non-null   object
#  5   country             4004 non-null   object
#  6   province            4004 non-null   object
#  7   city                3926 non-null   object
#  8   disease             18 non-null     object
#  9   infection_case      3211 non-null   object
#  10  infection_order     31 non-null     float64
#  11  infected_by         899 non-null    object
#  12  contact_number      680 non-null    object
#  13  symptom_onset_date  535 non-null    object
#  14  confirmed_date      4001 non-null   object
# ...

# %%
patient_info[patient_info['disease'].notnull()]
# Out:
#       patient_id  global_num     sex birth_year  age country  \
# 1012  1200000038        38.0  female       1963  50s   Korea
# 1055  1200001288      1288.0    male       1955  60s   Korea
# 1057  1200001921      1921.0    male       1953  60s   Korea
# 1058  1200002085      2085.0    male       1949  70s   Korea
# 1060  1200002614      2614.0  female       1943  70s   Korea
# 1065  1200003896      3896.0    male       1933  80s   Korea
# 1066  1200003914      3914.0    male       1938  80s   Korea
# 1067  1200004046      4046.0  female       1962  50s   Korea
# 1068  1200005767      5767.0    male       1938  80s   Korea
# 1069  1200007196      7196.0    male       1945  70s   Korea
# 2371  3014000001         NaN  female        NaN  80s   Korea
# 3757  6020100054        54.0    male       1963  50s   Korea
# 3758  6020100055        55.0    male       1961  50s   Korea
# 3759  6020100104       104.0    male       1957  60s   Korea
# ...

# %%
patient_info[patient_info['global_num'] == 31.0]
# Out:
#       patient_id  global_num     sex birth_year  age country province city  \
# 1007  1200000031        31.0  female       1959  60s   Korea    Daegu  NaN
#
#      disease      infection_case  infection_order infected_by contact_number  \
# 1007     NaN  Shincheonji Church              NaN         NaN           1160
#
#      symptom_onset_date confirmed_date released_date deceased_date     state
# 1007                NaN     2020-02-18           NaN           NaN  isolated

# %%
contact_number = patient_info['contact_number']
max_num = contact_number.argmax()
print(max_num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-dca9dd8571e2> in <module>
#       1 contact_number = patient_info['contact_number']
# ----> 2 max_num = contact_number.argmax()
#       3 print(max_num)
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in argmax(self, axis, skipna, *args, **kwargs)
#     943         nv.validate_minmax_axis(axis)
#     944         nv.validate_argmax_with_skipna(skipna, args, kwargs)
# --> 945         return nanops.nanargmax(self._values, skipna=skipna)
#     946
#     947     def min(self, axis=None, skipna=True, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      63                 f_name = f.__name__.replace("nan", "")
#      64                 raise TypeError(
# ---> 65                     f"reduction operation '{f_name}' not allowed for this dtype"
# ...

# %%
# 이게 왜 이렇게 나오는거지 
patient_info.sort_values(by=['contact_number'], ascending=False, na_position='last')
# Out:
#       patient_id  global_num     sex birth_year  age country  \
# 1478  2000000002         4.0    male       1964  50s   Korea
# 2628  6001000006       211.0  female       1974  40s   Korea
# 1333  1500000002       372.0  female        NaN  60s   Korea
# 2078  2000000602     10395.0  female       1995  20s   Korea
# 1846  2000000370      9091.0    male       1982  30s   Korea
# ...          ...         ...     ...        ...  ...     ...
# 3986  6100000119         NaN  female       1989  30s   Korea
# 3987  6100000120         NaN  female       1974  40s   Korea
# 3988  6100000121         NaN    male       1998  20s   Korea
# 3989  6100000122         NaN    male       1960  60s   Korea
# 4003  7000000014         NaN  female        NaN  30s   Korea
#
#               province           city disease        infection_case  \
# 1478       Gyeonggi-do  Pyeongtaek-si     NaN       overseas inflow
# 2628  Gyeongsangbuk-do   Gyeongsan-si     NaN                   NaN
# ...

# %%
#환자 동선 
# 환자id, 질병관리본부 부여번호, 날짜, 지역(특별시, 광역시, 도), 도시(시, 군, 구), 위도, 경도
patient_route = pd.read_csv(drive_path + 'PatientRoute.csv')
print(patient_route.info())
patient_route.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8092 entries, 0 to 8091
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   patient_id  8092 non-null   int64
#  1   global_num  4828 non-null   float64
#  2   date        8092 non-null   object
#  3   province    8092 non-null   object
#  4   city        8092 non-null   object
#  5   type        8092 non-null   object
#  6   latitude    8092 non-null   float64
#  7   longitude   8092 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 505.9+ KB
# None
#    patient_id  global_num        date     province          city  \
# 0  1000000001         2.0  2020-01-22  Gyeonggi-do      Gimpo-si
# 1  1000000001         2.0  2020-01-24        Seoul       Jung-gu
# 2  1000000002         5.0  2020-01-25        Seoul   Seongbuk-gu
# 3  1000000002         5.0  2020-01-26        Seoul   Seongbuk-gu
# ...

# %%
patient_route[patient_route['global_num'] == 31.0]
# Out:
#       patient_id  global_num        date          province          city  \
# 4868  1200000031        31.0  2020-02-06             Daegu       Dong-gu
# 4869  1200000031        31.0  2020-02-07             Daegu    Suseong-gu
# 4870  1200000031        31.0  2020-02-07             Daegu    Suseong-gu
# 4871  1200000031        31.0  2020-02-08             Daegu    Suseong-gu
# 4872  1200000031        31.0  2020-02-09             Daegu        Nam-gu
# 4873  1200000031        31.0  2020-02-09             Daegu        Nam-gu
# 4874  1200000031        31.0  2020-02-09             Daegu    Suseong-gu
# 4875  1200000031        31.0  2020-02-09             Daegu    Suseong-gu
# 4876  1200000031        31.0  2020-02-15             Daegu       Dong-gu
# 4877  1200000031        31.0  2020-02-15             Daegu    Suseong-gu
# 4878  1200000031        31.0  2020-02-16             Daegu        Nam-gu
# 4879  1200000031        31.0  2020-02-16             Daegu    Suseong-gu
# ...

# %%
#정책 아이디, 정책 시행국, 정책 타입, 정부 정책, 정책 상세, 시작일, 종료일
policy = pd.read_csv(drive_path + 'policy.csv')
print(policy.info())
policy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   policy_id   58 non-null     int64
#  1   country     58 non-null     object
#  2   type        58 non-null     object
#  3   gov_policy  58 non-null     object
#  4   detail      56 non-null     object
#  5   start_date  58 non-null     object
#  6   end_date    23 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 3.3+ KB
# None
#     policy_id country            type  \
# 0           1   Korea           Alert
# 1           2   Korea           Alert
# 2           3   Korea           Alert
# 3           4   Korea           Alert
# 4           5   Korea     Immigration
# 5           6   Korea     Immigration
# 6           7   Korea     Immigration
# 7           8   Korea     Immigration
# 8           9   Korea     Immigration
# 9          10   Korea     Immigration
# ...

# %%
#지역정보
#지역 코드, 지역(특별시, 광역시, 도), 도시(시, 군, 구), 위도, 경도, 초등학교수, 유치원수, 대학교수, 학원 비율, 독거노인 비율, 독거노인 가구 비율 , 요양원 수  
region = pd.read_csv(drive_path + 'region.csv')
print(region.info())
region.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      244 non-null    int64
#  1   province                  244 non-null    object
#  2   city                      244 non-null    object
#  3   latitude                  244 non-null    float64
#  4   longitude                 244 non-null    float64
#  5   elementary_school_count   244 non-null    int64
#  6   kindergarten_count        244 non-null    int64
#  7   university_count          244 non-null    int64
#  8   academy_ratio             244 non-null    float64
#  9   elderly_population_ratio  244 non-null    float64
#  10  elderly_alone_ratio       244 non-null    float64
#  11  nursing_home_count        244 non-null    int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 23.0+ KB
# None
# ...

# %%
# 검색 동향
#날짜, 감기, 독감, 폐렴, 코로나
search_trend = pd.read_csv(drive_path + 'SearchTrend.csv')
print(search_trend.info())
search_trend.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1613 entries, 0 to 1612
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1613 non-null   object
#  1   cold         1613 non-null   float64
#  2   flu          1613 non-null   float64
#  3   pneumonia    1613 non-null   float64
#  4   coronavirus  1613 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 63.1+ KB
# None
#          date     cold      flu  pneumonia  coronavirus
# 0  2016-01-01  0.11663  0.05590    0.15726      0.00736
# 1  2016-01-02  0.13372  0.17135    0.20826      0.00890
# 2  2016-01-03  0.14917  0.22317    0.19326      0.00845
# 3  2016-01-04  0.17463  0.18626    0.29008      0.01145
# 4  2016-01-05  0.17226  0.15072    0.24562      0.01381

# %%
#서울 유동인구
# 날짜, 시간, 연령대, 성별, 지역(특별시, 광역시, 도), 도시(시, 군, 구), 유동인구수
seoul_floating = pd.read_csv(drive_path + 'SeoulFloating.csv')
print(seoul_floating.info())
seoul_floating.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864000 entries, 0 to 863999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        864000 non-null  object
#  1   hour        864000 non-null  int64
#  2   birth_year  864000 non-null  int64
#  3   sex         864000 non-null  object
#  4   province    864000 non-null  object
#  5   city        864000 non-null  object
#  6   fp_num      864000 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 46.1+ MB
# None
#          date  hour  birth_year     sex province           city  fp_num
# 0  2020-01-01     0          20  female    Seoul      Dobong-gu   19140
# 1  2020-01-01     0          20    male    Seoul      Dobong-gu   19950
# 2  2020-01-01     0          20  female    Seoul  Dongdaemun-gu   25450
# 3  2020-01-01     0          20    male    Seoul  Dongdaemun-gu   27050
# ...

# %%
#현황
#날짜,  시간(0 = AM 12:00 / 16 = PM 04:00), 누적검사수, 음성, 확진, 완치, 사망
time = pd.read_csv(drive_path + 'Time.csv')
print(time.info())
time.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       133 non-null    object
#  1   time       133 non-null    int64
#  2   test       133 non-null    int64
#  3   negative   133 non-null    int64
#  4   confirmed  133 non-null    int64
#  5   released   133 non-null    int64
#  6   deceased   133 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 7.4+ KB
# None
#            date  time    test  negative  confirmed  released  deceased
# 128  2020-05-27     0  852876    820550      11265     10295       269
# 129  2020-05-28     0  868666    834952      11344     10340       269
# 130  2020-05-29     0  885120    849161      11402     10363       269
# 131  2020-05-30     0  902901    865162      11441     10398       269
# 132  2020-05-31     0  910822    876060      11468     10405       270

# %%
#연령대별 현황
#날짜, 시간(0 = AM 12:00 / 16 = PM 04:00), 연령대, 확진, 사망
time_age = pd.read_csv(drive_path + 'TimeAge.csv')
print(time_age.info())
time_age.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819 entries, 0 to 818
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       819 non-null    object
#  1   time       819 non-null    int64
#  2   age        819 non-null    object
#  3   confirmed  819 non-null    int64
#  4   deceased   819 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 32.1+ KB
# None
#            date  time  age  confirmed  deceased
# 814  2020-05-31     0  40s       1521         3
# 815  2020-05-31     0  50s       2039        15
# 816  2020-05-31     0  60s       1405        39
# 817  2020-05-31     0  70s        725        80
# 818  2020-05-31     0  80s        498       131

# %%
#성별별 현황
#날짜, 시간, 성별, 확진자, 사망
time_gender = pd.read_csv(drive_path + 'TimeGender.csv')
print(time_gender.info())
time_gender.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       182 non-null    object
#  1   time       182 non-null    int64
#  2   sex        182 non-null    object
#  3   confirmed  182 non-null    int64
#  4   deceased   182 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 7.2+ KB
# None
#            date  time     sex  confirmed  deceased
# 177  2020-05-29     0  female       6643       127
# 178  2020-05-30     0    male       4780       142
# 179  2020-05-30     0  female       6661       127
# 180  2020-05-31     0    male       4795       143
# 181  2020-05-31     0  female       6673       127

# %%
#지역별 현황
#날짜, 시간, 지역, 확진자, 완치, 사망
time_province = pd.read_csv(drive_path + 'TimeProvince.csv')
print(time_province.info())
time_province.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2261 entries, 0 to 2260
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2261 non-null   object
#  1   time       2261 non-null   int64
#  2   province   2261 non-null   object
#  3   confirmed  2261 non-null   int64
#  4   released   2261 non-null   int64
#  5   deceased   2261 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 106.1+ KB
# None
#             date  time          province  confirmed  released  deceased
# 2256  2020-05-31     0      Jeollabuk-do         21        19         0
# 2257  2020-05-31     0      Jeollanam-do         19        17         0
# 2258  2020-05-31     0  Gyeongsangbuk-do       1379      1295        54
# 2259  2020-05-31     0  Gyeongsangnam-do        123       121         0
# 2260  2020-05-31     0           Jeju-do         15        13         0

# %%
#날씨 
#지역 코드, 지역(특별시, 광역시, 도), 날짜, 평균기온, 최저기온, 최고기온, 일일강수량, 최고 풍속, 풍향, 평균 상대 습도 
weather = pd.read_csv(drive_path + 'Weather.csv')
print(weather.info())
weather.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25807 entries, 0 to 25806
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   code                   25807 non-null  int64
#  1   province               25807 non-null  object
#  2   date                   25807 non-null  object
#  3   avg_temp               25792 non-null  float64
#  4   min_temp               25802 non-null  float64
#  5   max_temp               25804 non-null  float64
#  6   precipitation          25807 non-null  float64
#  7   max_wind_speed         25798 non-null  float64
#  8   most_wind_direction    25778 non-null  float64
#  9   avg_relative_humidity  25787 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.0+ MB
# None
#         code          province        date  avg_temp  min_temp  max_temp  \
# 25802  50000      Jeollabuk-do  2020-05-31      20.9      17.3      26.7
# ...

# %% [markdown]
# ---
# 집단 발병이 일어난 원인 분석?
