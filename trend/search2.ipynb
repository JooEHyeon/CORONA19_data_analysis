# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
plt.rc('font',family=font_name)

# %%
df1 = pd.read_csv("./trend/datalab2_10대.csv")
df2 = pd.read_csv("./trend/datalab2_20대.csv")
df3 = pd.read_csv("./trend/datalab2_30대.csv")
df4 = pd.read_csv("./trend/datalab2_40대.csv")
df5 = pd.read_csv("./trend/datalab2_50대.csv")
df6 = pd.read_csv("./trend/datalab2_60대.csv")

# %%
display(df1.head(10))
display(df2.head(10))
display(df3.head(10))
display(df4.head(10))
display(df5.head(10))
display(df6.head(10))
# Out:
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-02
# 7  2019-09-03
# 8  2019-09-04
# 9  2019-09-05
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_dc003578c27c4245b87d45f689d37c2a  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-02 ~ 2020-09-02
# 3                                          전체(여성,남성)
# 4                                         ~12, 13~18
# 5                                                 캠핑
# 6                                            0.48208
# 7                                            0.46017
# 8                                            0.29582
# 9                                            0.40539
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# ...

# %%
df1.drop([0,1,2,3,4],inplace=True)
df2.drop([0,1,2,3,4],inplace=True)
df3.drop([0,1,2,3,4],inplace=True)
df4.drop([0,1,2,3,4],inplace=True)
df5.drop([0,1,2,3,4],inplace=True)
df6.drop([0,1,2,3,4],inplace=True)

# %%
df1 = df1.rename(columns=df1.iloc[0])
df2 = df2.rename(columns=df2.iloc[0])
df3 = df3.rename(columns=df3.iloc[0])
df4 = df4.rename(columns=df4.iloc[0])
df5 = df5.rename(columns=df5.iloc[0])
df6 = df6.rename(columns=df6.iloc[0])

# %%
df1.drop(df1.index[0],inplace=True)
df2.drop(df2.index[0],inplace=True)
df3.drop(df3.index[0],inplace=True)
df4.drop(df4.index[0],inplace=True)
df5.drop(df5.index[0],inplace=True)
df6.drop(df6.index[0],inplace=True)

# %%
df1 = df1.loc[:,~df1.columns.duplicated()]
df2 = df2.loc[:,~df2.columns.duplicated()]
df3 = df3.loc[:,~df3.columns.duplicated()]
df4 = df4.loc[:,~df4.columns.duplicated()]
df5 = df5.loc[:,~df5.columns.duplicated()]
df6 = df6.loc[:,~df6.columns.duplicated()]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 367 entries, 6 to 372
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      367 non-null    object
#  1   캠핑      367 non-null    object
#  2   산책      367 non-null    object
#  3   등산      367 non-null    object
#  4   모임      367 non-null    object
#  5   행사      367 non-null    object
# dtypes: object(6)
# memory usage: 20.1+ KB

# %%
df1['날짜'] = df1['날짜'].astype('datetime64')
df1['캠핑'] = df1['캠핑'].astype('float')
df1['산책'] = df1['산책'].astype('float')
df1['등산'] = df1['등산'].astype('float')
df1['모임'] = df1['모임'].astype('float')
df1['행사'] = df1['행사'].astype('float')

df2['날짜'] = df2['날짜'].astype('datetime64')
df2['캠핑'] = df2['캠핑'].astype('float')
df2['산책'] = df2['산책'].astype('float')
df2['등산'] = df2['등산'].astype('float')
df2['모임'] = df2['모임'].astype('float')
df2['행사'] = df2['행사'].astype('float')

df3['날짜'] = df3['날짜'].astype('datetime64')
df3['캠핑'] = df3['캠핑'].astype('float')
df3['산책'] = df3['산책'].astype('float')
df3['등산'] = df3['등산'].astype('float')
df3['모임'] = df3['모임'].astype('float')
df3['행사'] = df3['행사'].astype('float')

df4['날짜'] = df4['날짜'].astype('datetime64')
df4['캠핑'] = df4['캠핑'].astype('float')
df4['산책'] = df4['산책'].astype('float')
df4['등산'] = df4['등산'].astype('float')
df4['모임'] = df4['모임'].astype('float')
df4['행사'] = df4['행사'].astype('float')

df5['날짜'] = df5['날짜'].astype('datetime64')
df5['캠핑'] = df5['캠핑'].astype('float')
df5['산책'] = df5['산책'].astype('float')
df5['등산'] = df5['등산'].astype('float')
df5['모임'] = df5['모임'].astype('float')
df5['행사'] = df5['행사'].astype('float')

df6['날짜'] = df6['날짜'].astype('datetime64')
df6['캠핑'] = df6['캠핑'].astype('float')
df6['산책'] = df6['산책'].astype('float')
df6['등산'] = df6['등산'].astype('float')
df6['모임'] = df6['모임'].astype('float')
df6['행사'] = df6['행사'].astype('float')

# %%
df1 = df1.set_index('날짜')
df2 = df2.set_index('날짜')
df3 = df3.set_index('날짜')
df4 = df4.set_index('날짜')
df5 = df5.set_index('날짜')
df6 = df6.set_index('날짜')

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df3.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df4.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df5.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df6.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>
