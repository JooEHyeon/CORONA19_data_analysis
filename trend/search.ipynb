# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
plt.rc('font',family=font_name)

# %%
df1 = pd.read_csv("./trend/datalab1_10대.csv")
df2 = pd.read_csv("./trend/datalab1_20대.csv")
df3 = pd.read_csv("./trend/datalab1_30대.csv")
df4 = pd.read_csv("./trend/datalab1_40대.csv")
df5 = pd.read_csv("./trend/datalab1_50대.csv")
df6 = pd.read_csv("./trend/datalab1_60대.csv")

# %%
display(df1.head(10))
display(df2.head(10))
display(df3.head(10))
display(df4.head(10))
display(df5.head(10))
display(df6.head(10))
# Out:
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-02
# 7  2019-09-03
# 8  2019-09-04
# 9  2019-09-05
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_34fd8e01837ddce72b78932bb106eb7d  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-02 ~ 2020-09-02
# 3                                          전체(여성,남성)
# 4                                         ~12, 13~18
# 5                                                 여행
# 6                                            0.09207
# 7                                            0.09606
# 8                                             0.0674
# 9                                            0.08948
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN        NaN         NaN        NaN         NaN        NaN
# 2         NaN        NaN         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4         NaN        NaN         NaN        NaN         NaN        NaN
# 5          날짜         카페          날짜        코로나          날짜        마스크
# 6  2019-09-02    0.32436  2019-09-02    0.00845  2019-09-02     0.0256
# 7  2019-09-03     0.4479  2019-09-03    0.00634  2019-09-03    0.02348
# 8  2019-09-04    0.34291  2019-09-04    0.00516  2019-09-04    0.01644
# 9  2019-09-05    0.33939  2019-09-05    0.00775  2019-09-05    0.02466
#
#    Unnamed: 8 Unnamed: 9
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5          날짜       넷플릭스
# 6  2019-09-02    2.88121
# 7  2019-09-03    2.76025
# 8  2019-09-04    2.80253
# 9  2019-09-05    2.92842
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-02
# 7  2019-09-03
# 8  2019-09-04
# 9  2019-09-05
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_187ddd8039db54ca0f008157d06790b5  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-02 ~ 2020-09-02
# 3                                          전체(여성,남성)
# 4                                       30~34, 35~39
# 5                                                 여행
# 6                                            0.06234
# 7                                            0.06372
# 8                                            0.05684
# 9                                            0.05655
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN        NaN         NaN        NaN         NaN        NaN
# 2         NaN        NaN         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4         NaN        NaN         NaN        NaN         NaN        NaN
# 5          날짜         카페          날짜        코로나          날짜        마스크
# 6  2019-09-02    0.26107  2019-09-02    0.00854  2019-09-02    0.03534
# 7  2019-09-03    0.27619  2019-09-03    0.00756  2019-09-03    0.03839
# 8  2019-09-04    0.25096  2019-09-04    0.00922  2019-09-04    0.03357
# 9  2019-09-05    0.25037  2019-09-05    0.00864  2019-09-05    0.03515
#
#    Unnamed: 8 Unnamed: 9
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5          날짜       넷플릭스
# 6  2019-09-02    0.87945
# 7  2019-09-03    0.86727
# 8  2019-09-04    0.89928
# 9  2019-09-05     0.8766
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-02
# 7  2019-09-03
# 8  2019-09-04
# 9  2019-09-05
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_dc825ac6d949fd8b57c30047cdf5f5b0  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-02 ~ 2020-09-02
# 3                                          전체(여성,남성)
# 4                                       30~34, 35~39
# 5                                                 여행
# 6                                            0.15876
# 7                                             0.1565
# 8                                             0.1459
# 9                                            0.13687
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN        NaN         NaN        NaN         NaN        NaN
# 2         NaN        NaN         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4         NaN        NaN         NaN        NaN         NaN        NaN
# 5          날짜         카페          날짜        코로나          날짜        마스크
# 6  2019-09-02    1.09664  2019-09-02    0.00854  2019-09-02    0.03534
# 7  2019-09-03    1.35349  2019-09-03    0.00756  2019-09-03    0.03839
# 8  2019-09-04    1.08741  2019-09-04    0.00922  2019-09-04    0.03357
# 9  2019-09-05     1.0281  2019-09-05    0.00864  2019-09-05    0.03515
#
#    Unnamed: 8 Unnamed: 9
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5          날짜       넷플릭스
# 6  2019-09-02    4.17752
# 7  2019-09-03     4.1299
# 8  2019-09-04    4.31066
# 9  2019-09-05    4.28346
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-02
# 7  2019-09-03
# 8  2019-09-04
# 9  2019-09-05
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_10fd4644f02bf63bfbb8b493ac516e79  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-02 ~ 2020-09-02
# 3                                          전체(여성,남성)
# 4                                       40~44, 45~49
# 5                                                 여행
# 6                                            0.25391
# 7                                            0.26847
# 8                                            0.26097
# 9                                            0.25573
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN        NaN         NaN        NaN         NaN        NaN
# 2         NaN        NaN         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4         NaN        NaN         NaN        NaN         NaN        NaN
# 5          날짜         카페          날짜        코로나          날짜        마스크
# 6  2019-09-02    1.16765  2019-09-02    0.01251  2019-09-02    0.05255
# 7  2019-09-03    1.36537  2019-09-03    0.01069  2019-09-03    0.05073
# 8  2019-09-04    1.17538  2019-09-04    0.01023  2019-09-04    0.04595
# 9  2019-09-05    1.17174  2019-09-05    0.00887  2019-09-05    0.05096
#
#    Unnamed: 8 Unnamed: 9
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5          날짜       넷플릭스
# 6  2019-09-02    4.60417
# 7  2019-09-03    4.59735
# 8  2019-09-04    4.78824
# 9  2019-09-05    4.72476
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-02
# 7  2019-09-03
# 8  2019-09-04
# 9  2019-09-05
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_819ed545be997e7450ee2ab3caf8c829  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-02 ~ 2020-09-02
# 3                                          전체(여성,남성)
# 4                                       50~54, 55~59
# 5                                                 여행
# 6                                            0.38007
# 7                                            0.40681
# 8                                              0.406
# 9                                            0.36953
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN        NaN         NaN        NaN         NaN        NaN
# 2         NaN        NaN         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4         NaN        NaN         NaN        NaN         NaN        NaN
# 5          날짜         카페          날짜        코로나          날짜        마스크
# 6  2019-09-02    1.19289  2019-09-02    0.01215  2019-09-02    0.04538
# 7  2019-09-03      1.295  2019-09-03    0.01863  2019-09-03    0.06564
# 8  2019-09-04    1.17425  2019-09-04    0.01458  2019-09-04    0.06158
# 9  2019-09-05    1.16534  2019-09-05    0.01053  2019-09-05    0.05348
#
#    Unnamed: 8 Unnamed: 9
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5          날짜       넷플릭스
# 6  2019-09-02    5.79349
# 7  2019-09-03    5.63871
# 8  2019-09-04    5.98961
# 9  2019-09-05    6.11522
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-02
# 7  2019-09-03
# 8  2019-09-04
# 9  2019-09-05
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_6bf76c9115b5827f23dffaad1ca8d20a  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-02 ~ 2020-09-02
# 3                                          전체(여성,남성)
# 4                                                60~
# 5                                                 여행
# 6                                            0.55867
# 7                                            0.51313
# 8                                             0.5192
# 9                                             0.4524
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN        NaN         NaN        NaN         NaN        NaN
# 2         NaN        NaN         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4         NaN        NaN         NaN        NaN         NaN        NaN
# 5          날짜         카페          날짜        코로나          날짜        마스크
# 6  2019-09-02    1.48474  2019-09-02    0.01821  2019-09-02    0.06072
# 7  2019-09-03    1.63959  2019-09-03    0.02429  2019-09-03    0.06983
# 8  2019-09-04     1.2388  2019-09-04     0.0091  2019-09-04    0.03339
# 9  2019-09-05    1.22362  2019-09-05    0.01214  2019-09-05    0.05161
#
#    Unnamed: 8 Unnamed: 9
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5          날짜       넷플릭스
# 6  2019-09-02    6.31243
# 7  2019-09-03    6.12722
# 8  2019-09-04    6.05738
# 9  2019-09-05    6.62213

# %%
df1.drop([0,1,2,3,4],inplace=True)
df2.drop([0,1,2,3,4],inplace=True)
df3.drop([0,1,2,3,4],inplace=True)
df4.drop([0,1,2,3,4],inplace=True)
df5.drop([0,1,2,3,4],inplace=True)
df6.drop([0,1,2,3,4],inplace=True)

# %%
df1 = df1.rename(columns=df1.iloc[0])
df2 = df2.rename(columns=df2.iloc[0])
df3 = df3.rename(columns=df3.iloc[0])
df4 = df4.rename(columns=df4.iloc[0])
df5 = df5.rename(columns=df5.iloc[0])
df6 = df6.rename(columns=df6.iloc[0])

# %%
df1.drop(df1.index[0],inplace=True)
df2.drop(df2.index[0],inplace=True)
df3.drop(df3.index[0],inplace=True)
df4.drop(df4.index[0],inplace=True)
df5.drop(df5.index[0],inplace=True)
df6.drop(df6.index[0],inplace=True)

# %%
df1 = df1.loc[:,~df1.columns.duplicated()]
df2 = df2.loc[:,~df2.columns.duplicated()]
df3 = df3.loc[:,~df3.columns.duplicated()]
df4 = df4.loc[:,~df4.columns.duplicated()]
df5 = df5.loc[:,~df5.columns.duplicated()]
df6 = df6.loc[:,~df6.columns.duplicated()]

# %%
df1['날짜'] = df1['날짜'].astype('datetime64')
df1['여행'] = df1['여행'].astype('float')
df1['카페'] = df1['카페'].astype('float')
df1['코로나'] = df1['코로나'].astype('float')
df1['마스크'] = df1['마스크'].astype('float')
df1['넷플릭스'] = df1['넷플릭스'].astype('float')

df2['날짜'] = df2['날짜'].astype('datetime64')
df2['여행'] = df2['여행'].astype('float')
df2['카페'] = df2['카페'].astype('float')
df2['코로나'] = df2['코로나'].astype('float')
df2['마스크'] = df2['마스크'].astype('float')
df2['넷플릭스'] = df2['넷플릭스'].astype('float')

df3['날짜'] = df3['날짜'].astype('datetime64')
df3['여행'] = df3['여행'].astype('float')
df3['카페'] = df3['카페'].astype('float')
df3['코로나'] = df3['코로나'].astype('float')
df3['마스크'] = df3['마스크'].astype('float')
df3['넷플릭스'] = df3['넷플릭스'].astype('float')

df4['날짜'] = df4['날짜'].astype('datetime64')
df4['여행'] = df4['여행'].astype('float')
df4['카페'] = df4['카페'].astype('float')
df4['코로나'] = df4['코로나'].astype('float')
df4['마스크'] = df4['마스크'].astype('float')
df4['넷플릭스'] = df4['넷플릭스'].astype('float')

df5['날짜'] = df5['날짜'].astype('datetime64')
df5['여행'] = df5['여행'].astype('float')
df5['카페'] = df5['카페'].astype('float')
df5['코로나'] = df5['코로나'].astype('float')
df5['마스크'] = df5['마스크'].astype('float')
df5['넷플릭스'] = df5['넷플릭스'].astype('float')

df6['날짜'] = df6['날짜'].astype('datetime64')
df6['여행'] = df6['여행'].astype('float')
df6['카페'] = df6['카페'].astype('float')
df6['코로나'] = df6['코로나'].astype('float')
df6['마스크'] = df6['마스크'].astype('float')
df6['넷플릭스'] = df6['넷플릭스'].astype('float')

# %%
df1 = df1.set_index('날짜')
df2 = df2.set_index('날짜')
df3 = df3.set_index('날짜')
df4 = df4.set_index('날짜')
df5 = df5.set_index('날짜')
df6 = df6.set_index('날짜')

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df3.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df4.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df5.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df6.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
# series_time = pd.Series(range(len(df['날짜'])),index=df['날짜'])
