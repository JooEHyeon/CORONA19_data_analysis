# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
plt.rc('font',family=font_name)

# %%
df1 = pd.read_csv("./trend/datalab3_10대.csv")
df2 = pd.read_csv("./trend/datalab3_20대.csv")
df3 = pd.read_csv("./trend/datalab3_30대.csv")
df4 = pd.read_csv("./trend/datalab3_40대.csv")
df5 = pd.read_csv("./trend/datalab3_50대.csv")
df6 = pd.read_csv("./trend/datalab3_60대.csv")

# %%
display(df1.head(10))
display(df2.head(10))
display(df3.head(10))
display(df4.head(10))
display(df5.head(10))
display(df6.head(10))
# Out:
#           url  \
# 0          주제
# 1          범위
# 2          기간
# 3          성별
# 4         연령대
# 5          날짜
# 6  2019-09-03
# 7  2019-09-04
# 8  2019-09-05
# 9  2019-09-06
#
#   http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_2e2acae148ad95c07aec0656f55a3065  \
# 0                                                 통검
# 1                                                 합계
# 2                       일간 : 2019-09-03 ~ 2020-09-03
# 3                                          전체(여성,남성)
# 4                                         ~12, 13~18
# 5                                                 맛집
# 6                                            16.0606
# 7                                           13.33333
# 8                                           15.85858
# 9                                           20.30303
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# ...

# %%
df1.drop([0,1,2,3,4],inplace=True)
df2.drop([0,1,2,3,4],inplace=True)
df3.drop([0,1,2,3,4],inplace=True)
df4.drop([0,1,2,3,4],inplace=True)
df5.drop([0,1,2,3,4],inplace=True)
df6.drop([0,1,2,3,4],inplace=True)

# %%
df1 = df1.rename(columns=df1.iloc[0])
df2 = df2.rename(columns=df2.iloc[0])
df3 = df3.rename(columns=df3.iloc[0])
df4 = df4.rename(columns=df4.iloc[0])
df5 = df5.rename(columns=df5.iloc[0])
df6 = df6.rename(columns=df6.iloc[0])

# %%
df1.drop(df1.index[0],inplace=True)
df2.drop(df2.index[0],inplace=True)
df3.drop(df3.index[0],inplace=True)
df4.drop(df4.index[0],inplace=True)
df5.drop(df5.index[0],inplace=True)
df6.drop(df6.index[0],inplace=True)

# %%
df1 = df1.loc[:,~df1.columns.duplicated()]
df2 = df2.loc[:,~df2.columns.duplicated()]
df3 = df3.loc[:,~df3.columns.duplicated()]
df4 = df4.loc[:,~df4.columns.duplicated()]
df5 = df5.loc[:,~df5.columns.duplicated()]
df6 = df6.loc[:,~df6.columns.duplicated()]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 367 entries, 6 to 372
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      367 non-null    object
#  1   맛집      367 non-null    object
#  2   호텔      367 non-null    object
#  3   축제      367 non-null    object
#  4   공연      367 non-null    object
#  5   여행      367 non-null    object
# dtypes: object(6)
# memory usage: 20.1+ KB

# %%
df1['날짜'] = df1['날짜'].astype('datetime64')
df1['맛집'] = df1['맛집'].astype('float')
df1['호텔'] = df1['호텔'].astype('float')
df1['축제'] = df1['축제'].astype('float')
df1['공연'] = df1['공연'].astype('float')
df1['여행'] = df1['여행'].astype('float')

df2['날짜'] = df2['날짜'].astype('datetime64')
df2['맛집'] = df2['맛집'].astype('float')
df2['호텔'] = df2['호텔'].astype('float')
df2['축제'] = df2['축제'].astype('float')
df2['공연'] = df2['공연'].astype('float')
df2['여행'] = df2['여행'].astype('float')

df3['날짜'] = df3['날짜'].astype('datetime64')
df3['맛집'] = df3['맛집'].astype('float')
df3['호텔'] = df3['호텔'].astype('float')
df3['축제'] = df3['축제'].astype('float')
df3['공연'] = df3['공연'].astype('float')
df3['여행'] = df3['여행'].astype('float')

df4['날짜'] = df4['날짜'].astype('datetime64')
df4['맛집'] = df4['맛집'].astype('float')
df4['호텔'] = df4['호텔'].astype('float')
df4['축제'] = df4['축제'].astype('float')
df4['공연'] = df4['공연'].astype('float')
df4['여행'] = df4['여행'].astype('float')

df5['날짜'] = df5['날짜'].astype('datetime64')
df5['맛집'] = df5['맛집'].astype('float')
df5['호텔'] = df5['호텔'].astype('float')
df5['축제'] = df5['축제'].astype('float')
df5['공연'] = df5['공연'].astype('float')
df5['여행'] = df5['여행'].astype('float')

df6['날짜'] = df6['날짜'].astype('datetime64')
df6['맛집'] = df6['맛집'].astype('float')
df6['호텔'] = df6['호텔'].astype('float')
df6['축제'] = df6['축제'].astype('float')
df6['공연'] = df6['공연'].astype('float')
df6['여행'] = df6['여행'].astype('float')

# %%
df1 = df1.set_index('날짜')
df2 = df2.set_index('날짜')
df3 = df3.set_index('날짜')
df4 = df4.set_index('날짜')
df5 = df5.set_index('날짜')
df6 = df6.set_index('날짜')

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df3.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df4.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df5.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df6.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %% [markdown]
# 맛집 - 맛집, 예약
# <br>
# 호텔 - 호텔, 호캉스
# <br>
# 축제 - 축제, 행사, 벚꽃축제
# <br>
# 공연 - 공연, 콘서트
# <br>
# 여행 - 여행, 방문, 관광
